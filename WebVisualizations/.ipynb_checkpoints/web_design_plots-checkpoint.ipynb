# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sem
from scipy.stats import linregress
import numpy as np

# %%
# File to Load 
cities_data = "Resources/cities.csv"

# Read School and store into Pandas DataFrames
cities_df = pd.read_csv(cities_data)

#View DataFrame
cities_df.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
#
#       Lng  Max Temp  Wind Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# 3   78.62     59.89        0.94
# 4  147.90     32.17        2.95

# %%
cities_df.to_html("cities_df.html", index = False)

# %%
#Create variables to graph
city_lat = cities_df["Lat"]
max_temp = cities_df["Max Temp"]
humidity = cities_df["Humidity"]
cloudiness = cities_df["Cloudiness"]
wind_speed = cities_df["Wind Speed"]

# %%
# assess relationship of variables 
x_values = city_lat
y_values = max_temp

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values, color = "navy")
# plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(6,5),fontsize=15,color="red")

# print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(linestyle='-', linewidth=1, fillstyle = "full")
plt.title("City Latitude vs. Max Temperature (1/5/17)")
plt.savefig("Resources/assets/images/Lat.MaxTemp.png", dpi=300)
plt.show()

# %%
# assess relationship of variables 
x_values = city_lat
y_values = humidity

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values, color = "navy")
# plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(6,5),fontsize=15,color="red")

# print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.grid(linestyle='-', linewidth=1, fillstyle = "full")
plt.title("City Latitude vs. Humidity (1/5/17)")
plt.savefig("Resources/assets/images/Lat.Humid.png", dpi=300)
plt.show()

# %%
# assess relationship of variables 
x_values = city_lat
y_values = cloudiness

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values, color = "navy")
# plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(6,5),fontsize=15,color="red")

# print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.grid(linestyle='-', linewidth=1, fillstyle = "full")
plt.title("City Latitude vs. Cloudiness (1/5/17)")
plt.savefig("Resources/assets/images/Lat.Cloud.png", dpi=300)
plt.show()

# %%
# assess relationship of variables 
x_values = city_lat
y_values = wind_speed

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values, color = "navy")
# plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(6,5),fontsize=15,color="red")

# print(f"The r-squared is: {rvalue**2}")
#add labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(linestyle='-', linewidth=1, fillstyle = "full")
plt.title("City Latitude vs. Wind Speed (1/5/17)")
plt.savefig("Resources/assets/images/Lat.Wind.png", dpi=300)
plt.show()
